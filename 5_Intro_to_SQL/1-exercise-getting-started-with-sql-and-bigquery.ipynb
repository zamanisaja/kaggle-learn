# %% [markdown]
# **This notebook is an exercise in the [SQL](https://www.kaggle.com/learn/intro-to-sql) course.  You can reference the tutorial at [this link](./1-getting-started-with-sql-and-bigquery.ipynb).**
#
# ---

# %% [markdown]
# # Introduction
#
# The first test of your new data exploration skills uses data describing crime in the city of Chicago.
#
# Before you get started, run the following cell. It sets up the automated feedback system to review your answers.

# %%
# Set up feedack system
from learntools.core import binder
binder.bind(globals())
from learntools.sql.ex1 import *
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# Use the next code cell to fetch the dataset.

# %%
from google.cloud import bigquery

# Create a "Client" object
client = bigquery.Client()

# Construct a reference to the "chicago_crime" dataset
dataset_ref = client.dataset("chicago_crime", project="bigquery-public-data")

# API request - fetch the dataset
dataset = client.get_dataset(dataset_ref)

# %% [markdown]
# # Exercises
#
# ### 1) Count tables in the dataset
#
# How many tables are in the Chicago Crime dataset?

# %%
tables = list(client.list_tables(dataset))
num_tables = len(tables)

for table in tables:
    print(table.table_id)
# Check your answer
# q_1.check()
# Out:
# crime

# %% [markdown]
# For a hint or the solution, uncomment the appropriate line below.

# %%
#q_1.hint()
#q_1.solution()

# %% [markdown]
# ### 2) Explore the table schema
#
# How many columns in the `crime` table have `TIMESTAMP` data?

# %%
# Write the code to figure out the answer
table_ref = dataset_ref.table("crime")

table = client.get_table(table_ref)

schema = table.schema

timestamp_fields = [field for field in schema if field.field_type == "TIMESTAMP" ]

print(schema)
print("---------------")
print(timestamp_fields)
# Out:
# [SchemaField('unique_key', 'INTEGER', 'REQUIRED', None, (), None), SchemaField('case_number', 'STRING', 'NULLABLE', None, (), None), SchemaField('date', 'TIMESTAMP', 'NULLABLE', None, (), None), SchemaField('block', 'STRING', 'NULLABLE', None, (), None), SchemaField('iucr', 'STRING', 'NULLABLE', None, (), None), SchemaField('primary_type', 'STRING', 'NULLABLE', None, (), None), SchemaField('description', 'STRING', 'NULLABLE', None, (), None), SchemaField('location_description', 'STRING', 'NULLABLE', None, (), None), SchemaField('arrest', 'BOOLEAN', 'NULLABLE', None, (), None), SchemaField('domestic', 'BOOLEAN', 'NULLABLE', None, (), None), SchemaField('beat', 'INTEGER', 'NULLABLE', None, (), None), SchemaField('district', 'INTEGER', 'NULLABLE', None, (), None), SchemaField('ward', 'INTEGER', 'NULLABLE', None, (), None), SchemaField('community_area', 'INTEGER', 'NULLABLE', None, (), None), SchemaField('fbi_code', 'STRING', 'NULLABLE', None, (), None), SchemaField('x_coordinate', 'FLOA
# ...

# %%
num_timestamp_fields = len(timestamp_fields) # Put your answer here

# Check your answer
q_2.check()
# Out:
# Correct

# %% [markdown]
# For a hint or the solution, uncomment the appropriate line below.

# %%
#q_2.hint()
#q_2.solution()

# %% [markdown]
# ### 3) Create a crime map
#
# If you wanted to create a map with a dot at the location of each crime, what are the names of the two fields you likely need to pull out of the `crime` table to plot the crimes on a map?

# %%
# Write the code here to explore the data so you can find the answer

# %%
fields_for_plotting = ['latitude', 'longitude'] # Put your answers here

# Check your answer
q_3.check()
# Out:
# Correct

# %% [markdown]
# For a hint or the solution, uncomment the appropriate line below.

# %%
#q_3.hint()
#q_3.solution()

# %% [markdown]
# Thinking about the question above, there are a few columns that appear to have geographic data. Look at a few values (with the `list_rows()` command) to see if you can determine their relationship.  Two columns will still be hard to interpret. But it should be obvious how the `location` column relates to `latitude` and `longitude`.

# %%
select_fields = [field for field in schema if field.name in ["longitude", "latitude", "location"]]

# %%
# Scratch space for your code
client.list_rows(table, selected_fields=select_fields, max_results=5).to_dataframe()
# Out:
#     latitude  longitude                       location
# 0  41.716912 -87.535282  (41.716912114, -87.535282442)
# 1  41.987094 -87.784019  (41.987094276, -87.784019175)
# 2  41.978512 -87.814409  (41.978511843, -87.814408627)
# 3  41.728045 -87.556737   (41.728044594, -87.55673679)
# 4  41.778325 -87.747781   (41.778324807, -87.74778139)

# %% [markdown]
# # Keep going
#
# You've looked at the schema, but you haven't yet done anything exciting with the data itself. Things get more interesting when you get to the data, so keep going to **[write your first SQL query](./2-select-from-where.ipynb).**

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/intro-to-sql/discussion) to chat with other learners.*
