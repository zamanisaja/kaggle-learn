# %% [markdown]
# **This notebook is an exercise in the [Intro to Deep Learning](https://www.kaggle.com/learn/intro-to-deep-learning) course.  You can reference the tutorial at [this link](./6-binary-classification.ipynb).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In this exercise, you'll build a model to predict hotel cancellations with a binary classifier.

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex6 import *

# %% [markdown]
# First, load the *Hotel Cancellations* dataset.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('../input/dl-course-data/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %% [markdown]
# # 1) Define Model #
#
# The model we'll use this time will have both batch normalization and dropout layers. To ease reading we've broken the diagram into blocks, but you can define it layer by layer as usual.
#
# Define a model with an architecture given by this diagram:
#
# <figure style="padding: 1em;">
# <img src="https://i.imgur.com/V04o59Z.png" width="400" alt="Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.">
# <figcaption style="textalign: center; font-style: italic"><center>Diagram of a binary classifier.</center></figcaption>
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import *

# YOUR CODE HERE: define the model given in the diagram
model = keras.Sequential(layers = [
    BatchNormalization(input_shape = input_shape),
    Dense(units=256, activation='relu'),
    BatchNormalization(),
    Dropout(rate=0.3),
    Dense(units=256, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(1, activation = 'sigmoid'),
])

# Check your answer
q_1.check()
# Out:
# 2022-08-23 16:49:40.528984: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Correct

# %% [markdown]
# # 2) Add Optimizer, Loss, and Metric #
#
# Now compile the model with the Adam optimizer and binary versions of the cross-entropy loss and accuracy metric.

# %%
import tensorflow as tf

# YOUR CODE HERE
model.compile(
    optimizer='adam',
    loss="binary_crossentropy",
    metrics=["binary_accuracy"]

    # optimizer=tf.keras.optimizers.Adam(),
    # loss=tf.losses.BinaryCrossentropy(),
    # metrics=[tf.keras.metrics.BinaryAccuracy()],
)

# Check your answer
q_2.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
# q_2.solution()

# %% [markdown]
# Finally, run this cell to train the model and view the learning curves. It may run for around 60 to 70 epochs, which could take a minute or two.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/200
# 175/175 [==============================] - 3s 13ms/step - loss: 0.4845 - binary_accuracy: 0.7720 - val_loss: 0.4327 - val_binary_accuracy: 0.8030
# Epoch 2/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.4247 - binary_accuracy: 0.7996 - val_loss: 0.3996 - val_binary_accuracy: 0.8142
# Epoch 3/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.4112 - binary_accuracy: 0.8085 - val_loss: 0.3927 - val_binary_accuracy: 0.8185
# Epoch 4/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.4023 - binary_accuracy: 0.8115 - val_loss: 0.3875 - val_binary_accuracy: 0.8203
# Epoch 5/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3973 - binary_accuracy: 0.8150 - val_loss: 0.3848 - val_binary_accuracy: 0.8249
# Epoch 6/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3929 - binary_accuracy: 0.8167 - val_loss: 0.3824 - val_binary_accuracy: 0.8259
# Epoch 7/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3899 - binary_accuracy: 0.8181 - val_loss: 0.3810 - val_binary_accuracy: 0.8265
# Epoch 8/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3862 - binary_accuracy: 0.8193 - val_loss: 0.3786 - val_binary_accuracy: 0.8295
# Epoch 9/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3835 - binary_accuracy: 0.8216 - val_loss: 0.3816 - val_binary_accuracy: 0.8278
# Epoch 10/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3796 - binary_accuracy: 0.8230 - val_loss: 0.3744 - val_binary_accuracy: 0.8316
# Epoch 11/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3764 - binary_accuracy: 0.8253 - val_loss: 0.3771 - val_binary_accuracy: 0.8298
# Epoch 12/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3748 - binary_accuracy: 0.8261 - val_loss: 0.3692 - val_binary_accuracy: 0.8323
# Epoch 13/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3735 - binary_accuracy: 0.8259 - val_loss: 0.3716 - val_binary_accuracy: 0.8323
# Epoch 14/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3708 - binary_accuracy: 0.8272 - val_loss: 0.3669 - val_binary_accuracy: 0.8332
# Epoch 15/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3680 - binary_accuracy: 0.8297 - val_loss: 0.3682 - val_binary_accuracy: 0.8352
# Epoch 16/200
# 175/175 [==============================] - 1s 9ms/step - loss: 0.3664 - binary_accuracy: 0.8309 - val_loss: 0.3652 - val_binary_accuracy: 0.8364
# Epoch 17/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3646 - binary_accuracy: 0.8307 - val_loss: 0.3683 - val_binary_accuracy: 0.8351
# Epoch 18/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3642 - binary_accuracy: 0.8309 - val_loss: 0.3641 - val_binary_accuracy: 0.8346
# Epoch 19/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3612 - binary_accuracy: 0.8337 - val_loss: 0.3628 - val_binary_accuracy: 0.8368
# Epoch 20/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3586 - binary_accuracy: 0.8333 - val_loss: 0.3612 - val_binary_accuracy: 0.8358
# Epoch 21/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3587 - binary_accuracy: 0.8342 - val_loss: 0.3612 - val_binary_accuracy: 0.8357
# Epoch 22/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3580 - binary_accuracy: 0.8335 - val_loss: 0.3590 - val_binary_accuracy: 0.8379
# Epoch 23/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3560 - binary_accuracy: 0.8360 - val_loss: 0.3567 - val_binary_accuracy: 0.8383
# Epoch 24/200
# 175/175 [==============================] - 1s 9ms/step - loss: 0.3553 - binary_accuracy: 0.8361 - val_loss: 0.3576 - val_binary_accuracy: 0.8387
# Epoch 25/200
# 175/175 [==============================] - 1s 8ms/step - loss: 0.3547 - binary_accuracy: 0.8359 - val_loss: 0.3560 - val_binary_accuracy: 0.8386
# Epoch 26/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3523 - binary_accuracy: 0.8364 - val_loss: 0.3556 - val_binary_accuracy: 0.8401
# Epoch 27/200
# 175/175 [==============================] - 1s 9ms/step - loss: 0.3504 - binary_accuracy: 0.8386 - val_loss: 0.3574 - val_binary_accuracy: 0.8378
# Epoch 28/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3498 - binary_accuracy: 0.8386 - val_loss: 0.3552 - val_binary_accuracy: 0.8408
# Epoch 29/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3506 - binary_accuracy: 0.8371 - val_loss: 0.3583 - val_binary_accuracy: 0.8384
# Epoch 30/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3479 - binary_accuracy: 0.8389 - val_loss: 0.3534 - val_binary_accuracy: 0.8404
# Epoch 31/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3464 - binary_accuracy: 0.8398 - val_loss: 0.3548 - val_binary_accuracy: 0.8392
# Epoch 32/200
# 175/175 [==============================] - 1s 9ms/step - loss: 0.3479 - binary_accuracy: 0.8394 - val_loss: 0.3530 - val_binary_accuracy: 0.8405
# Epoch 33/200
# 175/175 [==============================] - 1s 9ms/step - loss: 0.3447 - binary_accuracy: 0.8393 - val_loss: 0.3540 - val_binary_accuracy: 0.8396
# Epoch 34/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3441 - binary_accuracy: 0.8404 - val_loss: 0.3527 - val_binary_accuracy: 0.8410
# Epoch 35/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3435 - binary_accuracy: 0.8412 - val_loss: 0.3533 - val_binary_accuracy: 0.8393
# <AxesSubplot:title={'center':'Accuracy'}>

# %% [markdown]
# # 3) Train and Evaluate #
#
#
# What do you think about the learning curves? Does it look like the model underfit or overfit? Was the cross-entropy loss a good stand-in for accuracy?

# %%
# View the solution (Run this cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
# Though we can see the training loss continuing to fall, the early stopping callback prevented any overfitting. Moreover, the accuracy rose at the same rate as the cross-entropy fell, so it appears that minimizing cross-entropy was a good stand-in. All in all, it looks like this training was a success!

# %% [markdown]
# # Conclusion #
#
# Congratulations! You've completed Kaggle's *Introduction to Deep Learning* course!
#
# With your new skills you're ready to take on more advanced applications like computer vision and sentiment classification. What would you like to do next?
#
# Why not try one of our *Getting Started* competitions?
#
# - Classify images with TPUs in [**Petals to the Metal**](https://www.kaggle.com/c/tpu-getting-started)
# - Create art with GANs in [**I'm Something of a Painter Myself**](https://www.kaggle.com/c/gan-getting-started)
# - Classify Tweets in [**Real or Not? NLP with Disaster Tweets**](https://www.kaggle.com/c/nlp-getting-started)
# - Detect contradiction and entailment in [**Contradictory, My Dear Watson**](https://www.kaggle.com/c/contradictory-my-dear-watson)
#
# Until next time, Kagglers!

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/intro-to-deep-learning/discussion) to chat with other learners.*
